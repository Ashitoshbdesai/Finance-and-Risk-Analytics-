# %% [markdown]
# ## Preparation

# %% [markdown]
# ### Preparing the Environment

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
sns.set_theme()
pd.set_option('display.max_columns',None)
import math

# %% [markdown]
# ### Importing data set

# %%
# read_csv File i.e All related Files

# Aviation files

AAL_df = pd.read_csv('AAL.csv')
ALGT_df = pd.read_csv('ALGT.csv')
ALK_df = pd.read_csv('ALK.csv')
DAL_df = pd.read_csv('DAL.csv')
HA_df = pd.read_csv('HA.csv')
LUV_df = pd.read_csv('LUV.csv')

# Finance files
BCS_df = pd.read_csv('BCS.csv')
CS_df = pd.read_csv('CS.csv')
DB_df = pd.read_csv('DB.csv')
GS_df = pd.read_csv('GS.csv')
MS_df = pd.read_csv('MS.csv')
WFC_df = pd.read_csv('WFC.csv')

# Pharma_Healthcare
BHC_df = pd.read_csv('BHC.csv')
JNJ_df = pd.read_csv('JNJ.csv')
MRK_df = pd.read_csv('MRK.csv')
PFE_df = pd.read_csv('PFE.csv')
RHHBY_df = pd.read_csv('RHHBY.csv')
UNH_df = pd.read_csv('UNH.csv')

# Technology
AAPL_df = pd.read_csv('AAPL.csv')
AMZN_df = pd.read_csv('AMZN.csv')
FB_df = pd.read_csv('FB.csv')
GOOG_df = pd.read_csv('GOOG.csv')
IBM_df = pd.read_csv('IBM.csv')
MSFT_df = pd.read_csv('MSFT.csv')

# S&P500
SP500_df = pd.read_csv('S&P500.csv')

# %%
# All outputs
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %% [markdown]
# ### Data Cleaning and Manipulation

# %%
# Action steps - observe data - check for null or missing values - perform sanity check

# %%
# Checking Aviation data

print('---------AAL-----------')
AAL_df.head()

print('---------ALGT-----------')
ALGT_df.head()

print('---------ALK-----------')
ALK_df.head()

print('---------DAL-----------')
DAL_df.head()

print('---------HA-----------')
HA_df.head()

print('---------LUV-----------')
LUV_df.head()
# Out:
# ---------AAL-----------
#          Date  Open  High   Low  Close  Adj Close   Volume
# 0  01-10-2010  9.29  9.39  9.21   9.29   8.758067  3603800
# 1  04-10-2010  9.24  9.48  9.05   9.12   8.597802  3856800
# 2  05-10-2010  9.27  9.35  9.15   9.23   8.701504  3896600
# 3  06-10-2010  9.27  9.40  9.15   9.23   8.701504  3230200
# 4  07-10-2010  9.30  9.31  9.07   9.24   8.710930  3877700
# ---------ALGT-----------
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  01-10-2010  42.779999  43.259998  41.869999  43.230000  36.766212  159100.0
# 1  04-10-2010  43.250000  43.330002  41.310001  41.590000  35.371429  189700.0
# 2  05-10-2010  41.779999  42.130001  41.299999  42.099998  35.805168  175000.0
# 3  06-10-2010  42.080002  42.349998  41.349998  41.950001  35.677608  187200.0
# 4  07-10-2010  42.259998  42.270000  41.500000  41.700001  35.464993  162700.0
# ---------ALK-----------
#          Date     Open     High      Low    Close  Adj Close     Volume
# 0  01-10-2010  12.9325  12.9625  12.3675  12.4475  10.972344  1663600.0
# 1  04-10-2010  12.4300  12.5900  11.9975  12.1425  10.703489  1512400.0
# 2  05-10-2010  12.2600  12.2850  11.9450  12.2150  10.767396  2567200.0
# 3  06-10-2010  12.2200  12.3950  12.0875  12.1875  10.743157  1043600.0
# 1  04-10-2010  153.949997  155.960007  152.789993  155.389999  155.389999
# 2  05-10-2010  157.080002  161.210007  157.009995  160.869995  160.869995
# 3  06-10-2010  160.600006  160.679993  154.600006  155.399994  155.399994
# 4  07-10-2010  156.509995  157.399994  153.389999  156.270004  156.270004
#
#       Volume
# 0  8683400.0
# 1  5346500.0
# 2  5620000.0
# 3  6060800.0
# 4  4622000.0
# ---------FB-----------
#          Date       Open       High        Low      Close  Adj Close  \
# 0  18-05-2012  42.049999  45.000000  38.000000  38.230000  38.230000
# 1  21-05-2012  36.529999  36.660000  33.000000  34.029999  34.029999
# 2  22-05-2012  32.610001  33.590000  30.940001  31.000000  31.000000
# 3  23-05-2012  31.370001  32.500000  31.360001  32.000000  32.000000
# 4  24-05-2012  32.950001  33.209999  31.770000  33.029999  33.029999
#
#         Volume
# 0  573576400.0
# 1  168192700.0
# 2  101786600.0
# 3   73600000.0
# 4   50237200.0
# ---------GOOG-----------
#          Date        Open        High         Low       Close   Adj Close  \
# 0  01-10-2010  264.010437  264.319275  260.523499  261.828613  261.828613
# 1  04-10-2010  261.494843  263.138702  258.456238  260.199707  260.199707
# 2  05-10-2010  263.203461  268.991760  262.291870  268.110046  268.110046
# 3  06-10-2010  268.623138  268.966858  263.980530  266.177307  266.177307
# 4  07-10-2010  267.103821  267.596985  263.582031  264.015411  264.015411
#
#       Volume
# 0  4466600.0
# 1  3895400.0
# 2  7040400.0
# 3  5545200.0
# 4  4809400.0
# ---------IBM-----------
#          Date        Open        High         Low       Close  Adj Close  \
# 0  01-10-2010  135.509995  136.279999  135.089996  135.639999  97.152512
# 1  04-10-2010  135.229996  135.919998  134.389999  135.250000  96.873192
# 2  05-10-2010  136.179993  137.899994  136.119995  137.660004  98.599335
# 3  06-10-2010  136.880005  137.960007  136.830002  137.839996  98.728279
# 4  07-10-2010  137.919998  138.880005  137.520004  138.720001  99.358559
#
#       Volume
# 0  5621200.0
# 1  4059900.0
# 2  6202500.0
# 3  4783000.0
# 4  6440800.0
# ---------MSFT-----------
#          Date       Open       High        Low      Close  Adj Close  \
# 0  01-10-2010  24.770000  24.820000  24.299999  24.379999  19.315863
# 1  04-10-2010  23.959999  23.990000  23.780001  23.910000  18.943493
# 2  05-10-2010  24.059999  24.450001  23.910000  24.350000  19.292101
# 3  06-10-2010  24.320000  24.540001  24.129999  24.430000  19.355482
# 4  07-10-2010  24.620001  24.750000  24.280001  24.530001  19.434708
#
#        Volume
# 0  62672300.0
# 1  98143400.0
# 2  78152900.0
# 3  50489700.0
# 4  50096100.0

# %%
# Dropping Rows Only if All the Values are Null

AAL_df.dropna(how='all',inplace = True)
ALGT_df.dropna(how='all',inplace = True)
ALK_df.dropna(how='all',inplace = True)
DAL_df.dropna(how='all',inplace = True)
HA_df.dropna(how='all',inplace = True)
LUV_df.dropna(how='all',inplace = True)
BCS_df.dropna(how='all',inplace = True)
CS_df.dropna(how='all',inplace = True)
DB_df.dropna(how='all',inplace = True)
GS_df.dropna(how='all',inplace = True)
MS_df.dropna(how='all',inplace = True)
WFC_df.dropna(how='all',inplace = True)
BHC_df.dropna(how='all',inplace = True)
JNJ_df.dropna(how='all',inplace = True)
MRK_df.dropna(how='all',inplace = True)
PFE_df.dropna(how='all',inplace = True)
RHHBY_df.dropna(how='all',inplace = True)
UNH_df.dropna(how='all',inplace = True)
AAPL_df.dropna(how='all',inplace = True)
AMZN_df.dropna(how='all',inplace = True)
FB_df.dropna(how='all',inplace = True)
GOOG_df.dropna(how='all',inplace = True)
IBM_df.dropna(how='all',inplace = True)
MSFT_df.dropna(how='all',inplace = True)
SP500_df.dropna(how='all',inplace = True)

# %%
# Keep required Columns

SP500_df = SP500_df[['Date','Close','Volume']]
AAL_df = AAL_df[['Date','Close','Volume']]
ALGT_df = ALGT_df[['Date','Close','Volume']]
ALK_df = ALK_df[['Date','Close','Volume']]
DAL_df = DAL_df[['Date','Close','Volume']]
HA_df = HA_df[['Date','Close','Volume']]
LUV_df = LUV_df[['Date','Close','Volume']]
BCS_df = BCS_df[['Date','Close','Volume']]
CS_df = CS_df[['Date','Close','Volume']]
DB_df = DB_df[['Date','Close','Volume']]
GS_df = GS_df[['Date','Close','Volume']]
MS_df = MS_df[['Date','Close','Volume']]
WFC_df = WFC_df[['Date','Close','Volume']]
BHC_df = BHC_df[['Date','Close','Volume']]
JNJ_df = JNJ_df[['Date','Close','Volume']]
MRK_df = MRK_df[['Date','Close','Volume']]
PFE_df = PFE_df[['Date','Close','Volume']]
RHHBY_df = RHHBY_df[['Date','Close','Volume']]
UNH_df = UNH_df[['Date','Close','Volume']]
AAPL_df = AAPL_df[['Date','Close','Volume']]
AMZN_df = AMZN_df[['Date','Close','Volume']]
MSFT_df = MSFT_df[['Date','Close','Volume']]
FB_df = FB_df[['Date','Close','Volume']]
GOOG_df = GOOG_df[['Date','Close','Volume']]
IBM_df = IBM_df[['Date','Close','Volume']]
MSFT_df = MSFT_df[['Date','Close','Volume']]

# %%
# Adding suffix to the columns of the dataframe for better readability

SP500_df.columns = SP500_df.columns.map(lambda x : x + '_SP500' if x !='Date'else x)
AAL_df.columns = AAL_df.columns.map(lambda x : x + '_AAL' if x !='Date'else x)
ALGT_df.columns = ALGT_df.columns.map(lambda x : x + '_ALGT' if x !='Date'else x)
ALK_df.columns = ALK_df.columns.map(lambda x : x + '_ALK' if x !='Date'else x)
DAL_df.columns = DAL_df.columns.map(lambda x : x + '_DAL' if x !='Date'else x)
HA_df.columns = HA_df.columns.map(lambda x : x + '_HA' if x !='Date'else x)
LUV_df.columns = LUV_df.columns.map(lambda x : x + '_LUV' if x !='Date'else x)
BCS_df.columns = BCS_df.columns.map(lambda x : x + '_BCS' if x !='Date'else x)
CS_df.columns = CS_df.columns.map(lambda x : x + '_CS' if x !='Date'else x)
DB_df.columns = DB_df.columns.map(lambda x : x + '_DB' if x !='Date'else x)
GS_df.columns = GS_df.columns.map(lambda x : x + '_GS' if x !='Date'else x)
MS_df.columns = MS_df.columns.map(lambda x : x + '_MS' if x !='Date'else x)
WFC_df.columns = WFC_df.columns.map(lambda x : x + '_WFC' if x !='Date'else x)
BHC_df.columns = BHC_df.columns.map(lambda x : x + '_BHC' if x !='Date'else x)
JNJ_df.columns = JNJ_df.columns.map(lambda x : x + '_JNJ' if x !='Date'else x)
MRK_df.columns = MRK_df.columns.map(lambda x : x + '_MRK' if x !='Date'else x)
PFE_df.columns = PFE_df.columns.map(lambda x : x + '_PFE' if x !='Date'else x)
RHHBY_df.columns = RHHBY_df.columns.map(lambda x : x + '_RHHBY' if x !='Date'else x)
UNH_df.columns = UNH_df.columns.map(lambda x : x + '_UNH' if x !='Date'else x)
AAPL_df.columns = AAPL_df.columns.map(lambda x : x + '_AAPL' if x !='Date'else x)
AMZN_df.columns = AMZN_df.columns.map(lambda x : x + '_AMZN' if x !='Date'else x)
FB_df.columns = FB_df.columns.map(lambda x : x + '_FB' if x !='Date'else x)
GOOG_df.columns = GOOG_df.columns.map(lambda x : x + '_GOOG' if x !='Date'else x)
IBM_df.columns = IBM_df.columns.map(lambda x : x + '_IBM' if x !='Date'else x)
MSFT_df.columns = MSFT_df.columns.map(lambda x : x + '_MSFT' if x !='Date'else x)

# %%
# Missing values treatment

print('No missing data -->SP500') if sum(SP500_df.isnull().sum()) == 0 else (SP500_df.isnull().sum())/len(SP500_df)
print('No missing data -->AAL') if sum(AAL_df.isnull().sum()) == 0 else (AAL_df.isnull().sum())/len(AAL_df)
print('No missing data -->ALGT') if sum(ALGT_df.isnull().sum()) == 0 else (ALGT_df.isnull().sum())/len(ALGT_df)
print('No missing data -->ALK') if sum(ALK_df.isnull().sum()) == 0 else (ALK_df.isnull().sum())/len(ALK_df)
print('No missing data -->DAL') if sum(DAL_df.isnull().sum()) == 0 else (DAL_df.isnull().sum())/len(DAL_df)
print('No missing data -->HA') if sum(HA_df.isnull().sum()) == 0 else (HA_df.isnull().sum())/len(HA_df)
print('No missing data -->LUV') if sum(LUV_df.isnull().sum()) == 0 else (LUV_df.isnull().sum())/len(LUV_df)
print('No missing data -->BCS') if sum(BCS_df.isnull().sum()) == 0 else (BCS_df.isnull().sum())/len(BCS_df)
print('No missing data -->Cs') if sum(CS_df.isnull().sum()) == 0 else (CS_df.isnull().sum())/len(CS_df)
print('No missing data -->DB') if sum(DB_df.isnull().sum()) == 0 else (DB_df.isnull().sum())/len(DB_df)
print('No missing data -->GS') if sum(GS_df.isnull().sum()) == 0 else (GS_df.isnull().sum())/len(GS_df)
print('No missing data -->MS') if sum(MS_df.isnull().sum()) == 0 else (MS_df.isnull().sum())/len(MS_df)
print('No missing data -->WFC ') if sum(WFC_df.isnull().sum()) == 0 else (WFC_df.isnull().sum())/len(WFC_df)
print('No missing data -->BHC') if sum(BHC_df.isnull().sum()) == 0 else (BHC_df.isnull().sum())/len(BHC_df)
print('No missing data -->JNJ') if sum(JNJ_df.isnull().sum()) == 0 else (JNJ_df.isnull().sum())/len(JNJ_df)
print('No missing data -->MRK') if sum(MRK_df.isnull().sum()) == 0 else (MRK_df.isnull().sum())/len(MRK_df)
print('No missing data -->PFE') if sum(PFE_df.isnull().sum()) == 0 else (PFE_df.isnull().sum())/len(PFE_df)
print('No missing data -->RHHBY') if sum(RHHBY_df.isnull().sum()) == 0 else (RHHBY_df.isnull().sum())/len(RHHBY_df)
print('No missing data -->UNH') if sum(UNH_df.isnull().sum()) == 0 else (UNH_df.isnull().sum())/len(UNH_df)
print('No missing data -->AAPL') if sum(AAPL_df.isnull().sum()) == 0 else (AAPL_df.isnull().sum())/len(AAPL_df)
print('No missing data -->AMZN') if sum(AMZN_df.isnull().sum()) == 0 else (AMZN_df.isnull().sum())/len(AMZN_df)
print('No missing data -->FB') if sum(FB_df.isnull().sum()) == 0 else (FB_df.isnull().sum())/len(FB_df)
print('No missing data -->GOOG') if sum(GOOG_df.isnull().sum()) == 0 else (GOOG_df.isnull().sum())/len(GOOG_df)
print('No missing data -->IBM') if sum(IBM_df.isnull().sum()) == 0 else (IBM_df.isnull().sum())/len(IBM_df)
print('No missing data -->MSFT') if sum(MSFT_df.isnull().sum()) == 0 else (MSFT_df.isnull().sum())/len(MSFT_df)
# Out:
# No missing data -->SP500
# No missing data -->AAL
# No missing data -->ALGT
# No missing data -->ALK
# No missing data -->DAL
# No missing data -->HA
# No missing data -->LUV
# No missing data -->BCS
# No missing data -->Cs
# No missing data -->DB
# No missing data -->GS
# No missing data -->MS
# No missing data -->WFC
# No missing data -->BHC
# No missing data -->JNJ
# No missing data -->MRK
# No missing data -->PFE
# No missing data -->RHHBY
# No missing data -->UNH
# No missing data -->AAPL
# No missing data -->AMZN
# No missing data -->FB
# No missing data -->GOOG
# No missing data -->IBM
# No missing data -->MSFT

# %%
# Merging the dataframes of All Industry and inspecting the dataframe

aviation_df = AAL_df.merge(ALGT_df, on = 'Date',how ='inner').merge(ALK_df, on = 'Date',how ='inner').merge(DAL_df, on = 'Date',how ='inner').merge(HA_df, on = 'Date',how ='inner').merge(LUV_df, on = 'Date',how ='inner')
finance_df  = BCS_df.merge(CS_df, on='Date',how='inner').merge(DB_df, on='Date',how='inner').merge(GS_df, on='Date',how='inner').merge(MS_df, on='Date',how='inner').merge(WFC_df, on='Date',how='inner')
healthcare_df = BHC_df.merge(JNJ_df, on='Date',how='inner').merge(MRK_df, on='Date',how='inner').merge(PFE_df, on='Date',how='inner').merge(RHHBY_df, on='Date',how='inner').merge(UNH_df, on='Date',how='inner')
technology_df = AAPL_df.merge(AMZN_df, on='Date',how='inner').merge(FB_df, on='Date',how='inner').merge(GOOG_df, on='Date',how='inner').merge(IBM_df, on='Date',how='inner').merge(MSFT_df, on='Date',how='inner')

# %%
print('-------------------------------------------------**AVIATION**-------------------------------------------------------------')
aviation_df.head()
print('-------------------------------------------------**FINANCE**-------------------------------------------------------------')
finance_df.head()
print('-------------------------------------------------**HEALTH CARE**-------------------------------------------------------------')
healthcare_df.head()
print('-------------------------------------------------**TECHNOLOGY**-------------------------------------------------------------')
technology_df.head()
# Out:
# -------------------------------------------------**AVIATION**-------------------------------------------------------------
#          Date  Close_AAL  Volume_AAL  Close_ALGT  Volume_ALGT  Close_ALK  \
# 0  01-10-2010       9.29     3603800   43.230000     159100.0    12.4475
# -------------------------------------------------**TECHNOLOGY**-------------------------------------------------------------
#          Date  Close_AAPL  Volume_AAPL  Close_AMZN  Volume_AMZN   Close_FB  \
# 0  18-05-2012   18.942142    732292400  213.850006    5231700.0  38.230000
# 1  21-05-2012   20.045713    631106000  218.110001    3579800.0  34.029999
# 2  22-05-2012   19.891787    694870400  215.330002    3733100.0  31.000000
# 3  23-05-2012   20.377142    584897600  217.279999    4243800.0  32.000000
# 4  24-05-2012   20.190001    496230000  215.240005    3141100.0  33.029999
#
#      Volume_FB  Close_GOOG  Volume_GOOG   Close_IBM  Volume_IBM  Close_MSFT  \
# 0  573576400.0  299.078979   11991700.0  195.880005   5737100.0   29.270000
# 1  168192700.0  305.908386    6173800.0  197.759995   3831700.0   29.750000
# 2  101786600.0  299.278229    6126600.0  196.820007   3567100.0   29.760000
# 3   73600000.0  303.592072    6379900.0  196.119995   4100000.0   29.110001
# 4   50237200.0  300.702881    3796600.0  196.089996   3569300.0   29.070000
#
#    Volume_MSFT
# 0   56205300.0
# 1   38787900.0
# 2   39504900.0
# 3   65171000.0
# 4   52575000.0

# %% [markdown]
# ## Observation
#
# ### The dataframes have been merged properly in their respective domains.

# %%
AllStocks_df = aviation_df.merge(finance_df, on='Date',how='inner').merge(healthcare_df, on = 'Date', how = 'inner').merge(technology_df,on='Date', how='inner').merge(SP500_df,on='Date', how = 'inner')
print('-------------------------------------------------**AVIATION**----------------------------------------------------------')
aviation_df.head()
print('-------------------------------------------------**ALL STOCKS MASTER FILE**---------------------------------------------------')
AllStocks_df.head()
# Out:
# -------------------------------------------------**AVIATION**----------------------------------------------------------
#          Date  Close_AAL  Volume_AAL  Close_ALGT  Volume_ALGT  Close_ALK  \
# 0  01-10-2010       9.29     3603800   43.230000     159100.0    12.4475
# 1  04-10-2010       9.12     3856800   41.590000     189700.0    12.1425
# 2  05-10-2010       9.23     3896600   42.099998     175000.0    12.2150
# 3  06-10-2010       9.23     3230200   41.950001     187200.0    12.1875
# 4  07-10-2010       9.24     3877700   41.700001     162700.0    11.6250
#
#    Volume_ALK  Close_DAL  Volume_DAL  Close_HA  Volume_HA  Close_LUV  \
# 0   1663600.0      12.01   9094900.0      5.96   645400.0      12.94
# 1   1512400.0      11.51   7916400.0      5.75   618900.0      12.82
# 2   2567200.0      11.83  12624100.0      5.85   534800.0      13.02
# 3   1043600.0      11.78  10124100.0      5.97  2563900.0      12.94
# 4   7682400.0      11.77   7162500.0      6.15  1115200.0      12.88
#
#    Volume_LUV
# 0   5722500.0
# 1   6537700.0
# 2   8060000.0
# 3   7457000.0
# 4   3413900.0
# -------------------------------------------------**ALL STOCKS MASTER FILE**---------------------------------------------------
#          Date  Close_AAL  Volume_AAL  Close_ALGT  Volume_ALGT  Close_ALK  \
# 0  18-05-2012      10.06    10813400   62.310001     167000.0  16.170000
# 1  21-05-2012      10.71     8290100   62.660000     150600.0  16.379999
# 2  22-05-2012      10.62     6227400   62.349998     125500.0  16.225000
# 3  23-05-2012      11.00     7233000   62.990002     166000.0  16.115000
# 3   73600000.0  303.592072    6379900.0  196.119995   4100000.0   29.110001
# 4   50237200.0  300.702881    3796600.0  196.089996   3569300.0   29.070000
#
#    Volume_MSFT  Close_SP500  Volume_SP500
# 0   56205300.0  1295.219971    4512470000
# 1   38787900.0  1315.989990    3786750000
# 2   39504900.0  1316.630005    4123680000
# 3   65171000.0  1318.859985    4108330000
# 4   52575000.0  1320.680054    3937670000

# %%
AllStocks_df.to_csv("AllStocks_df.csv")

# %%
# Checking the shape of the dataframe
AllStocks_df.shape
# Out:
# (2106, 51)

# %%
# Dropping duplicate values
AllStocks_df.drop_duplicates()
# Out:
#             Date  Close_AAL  Volume_AAL  Close_ALGT  Volume_ALGT  Close_ALK  \
# 0     18-05-2012      10.06    10813400   62.310001     167000.0  16.170000
# 1     21-05-2012      10.71     8290100   62.660000     150600.0  16.379999
# 2     22-05-2012      10.62     6227400   62.349998     125500.0  16.225000
# 3     23-05-2012      11.00     7233000   62.990002     166000.0  16.115000
# 4     24-05-2012      12.16    17085400   64.250000     148000.0  16.920000
# ...          ...        ...         ...         ...          ...        ...
# 2101  24-09-2020      11.77    49163200  121.500000     172300.0  35.700001
# 2102  25-09-2020      12.29    43764000  123.760002     115100.0  36.700001
# 2103  28-09-2020      12.76    63558200  127.110001     188400.0  37.540001
# 2104  29-09-2020      12.25    46994300  121.089996     187800.0  36.669998
# 2105  30-09-2020      12.29    65055100  119.800003     263000.0  36.630001
#
#       Volume_ALK  Close_DAL  Volume_DAL  Close_HA  Volume_HA  Close_LUV  \
# 0      2745800.0  10.140000  18994600.0      5.28   525400.0   8.150000
# 1      1361600.0  10.580000  14203200.0      5.32   327100.0   8.340000
# 2      1003600.0  10.540000  12860300.0      5.23   296000.0   8.270000
# 3      1626000.0  10.740000   9144000.0      5.38   348000.0   8.360000
# 4      1953800.0  11.270000  19379500.0      5.68   567300.0   8.740000
# ...          ...        ...         ...       ...        ...        ...
# 2101   3326000.0  29.010000  22257800.0     12.40   879700.0  36.860001
# 2102   1767600.0  29.780001  21831500.0     12.80   923400.0  37.099998
# 2103   2922800.0  31.340000  22098400.0     13.38  1076800.0  38.240002
# 2104   1743500.0  30.610001  14785600.0     12.86   953100.0  37.610001
# 2105   1921600.0  30.580000  16602100.0     12.89   916700.0  37.500000
#
#       Volume_LUV  Close_BCS  Volume_BCS   Close_CS  Volume_CS   Close_DB  \
# 0     15571300.0  10.285714   6799000.0  19.169922  5598100.0  34.370228
# 1     12843800.0  10.672812   4476600.0  19.541016  2003100.0  35.505726
# 2     10105100.0  10.857142   4883500.0  19.863281  3199100.0  35.410305
# 3     11985600.0  10.737328   4385300.0  19.765625  2216600.0  35.381680
# 4     15191400.0  10.746544   4550500.0  19.658203  1432400.0  34.828243
# ...          ...        ...         ...        ...        ...        ...
# 2101  10798800.0   4.750000   5312400.0   9.620000  2347300.0   8.110000
# 2102   9297300.0   4.700000   3185200.0   9.480000  2241100.0   8.000000
# 2103   9235200.0   4.990000   3486300.0   9.900000  2165500.0   8.430000
# ...          ...         ...         ...          ...          ...
# 2101  292.660004   2869100.0  108.220001    167743300  3019.790039
# 2102  302.500000   2455800.0  112.279999    149981400  3095.129883
# 2103  303.230011   2575700.0  114.959999    137672400  3174.050049
# 2104  304.149994   1797800.0  114.089996     99382200  3144.879883
# 2105  311.769989   3497300.0  115.809998    142675200  3148.729980
#
#       Volume_AMZN    Close_FB    Volume_FB   Close_GOOG  Volume_GOOG  \
# 0       5231700.0   38.230000  573576400.0   299.078979   11991700.0
# 1       3579800.0   34.029999  168192700.0   305.908386    6173800.0
# 2       3733100.0   31.000000  101786600.0   299.278229    6126600.0
# 3       4243800.0   32.000000   73600000.0   303.592072    6379900.0
# 4       3141100.0   33.029999   50237200.0   300.702881    3796600.0
# ...           ...         ...          ...          ...          ...
# 2101    5529400.0  249.529999   20006800.0  1428.290039    1450200.0
# 2102    4615200.0  254.820007   18351300.0  1444.959961    1323000.0
# 2103    4224200.0  256.820007   18826300.0  1464.520020    2007900.0
# 2104    3495800.0  261.790009   20200200.0  1469.329956     978200.0
# 2105    4883400.0  261.899994   20105800.0  1469.599976    1700600.0
#
#        Close_IBM  Volume_IBM  Close_MSFT  Volume_MSFT  Close_SP500  \
# 0     195.880005   5737100.0   29.270000   56205300.0  1295.219971
# 1     197.759995   3831700.0   29.750000   38787900.0  1315.989990
# 2     196.820007   3567100.0   29.760000   39504900.0  1316.630005
# 3     196.119995   4100000.0   29.110001   65171000.0  1318.859985
# 4     196.089996   3569300.0   29.070000   52575000.0  1320.680054
# ...          ...         ...         ...          ...          ...
# 2101  118.089996   3546200.0  203.190002   31202500.0  3246.590088
# 2102  118.949997   2953700.0  207.820007   29437300.0  3298.459961
# 2103  121.730003   3509200.0  209.440002   32004900.0  3351.600098
# 2104  120.940002   2106600.0  207.259995   24221900.0  3335.469971
# 2105  121.669998   3261100.0  210.330002   33780700.0  3363.000000
#
#       Volume_SP500
# 0       4512470000
# 1       3786750000
# 2       4123680000
# 3       4108330000
# 4       3937670000
# ...            ...
# 2101    4599470000
# 2102    3792220000
# 2103    3946060000
# 2104    3651880000
# 2105    4722530000
#
# [2106 rows x 51 columns]

# %% [markdown]
# No Duplicates Found!

# %% [markdown]
# Since we do not need first 5 years data, we shall make a new dataframe for all the stocks with only last 5 years data - From 01/10/2015 to 30/09/2020

# %% [markdown]
# ### Changing Datatype of Date Field to Datetime

# %%
AllStocks_df['Date'] = pd.to_datetime(AllStocks_df['Date'], infer_datetime_format=True)
AllStocks_df =AllStocks_df[(AllStocks_df['Date']>= '2015-10-01') & (AllStocks_df['Date']<= '2020-09-30')]

# %%
AllStocks_df.shape
# Out:
# (1259, 51)

# %% [markdown]
# #### Checking the Datatypes

# %%
AllStocks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1259 entries, 847 to 2105
# Data columns (total 51 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1259 non-null   datetime64[ns]
#  1   Close_AAL     1259 non-null   float64
#  2   Volume_AAL    1259 non-null   int64
#  3   Close_ALGT    1259 non-null   float64
#  4   Volume_ALGT   1259 non-null   float64
#  5   Close_ALK     1259 non-null   float64
#  6   Volume_ALK    1259 non-null   float64
#  7   Close_DAL     1259 non-null   float64
#  8   Volume_DAL    1259 non-null   float64
#  9   Close_HA      1259 non-null   float64
#  10  Volume_HA     1259 non-null   float64
#  11  Close_LUV     1259 non-null   float64
#  12  Volume_LUV    1259 non-null   float64
#  13  Close_BCS     1259 non-null   float64
#  14  Volume_BCS    1259 non-null   float64
#  15  Close_CS      1259 non-null   float64
#  16  Volume_CS     1259 non-null   float64
#  17  Close_DB      1259 non-null   float64
#  18  Volume_DB     1259 non-null   float64
#  19  Close_GS      1259 non-null   float64
#  20  Volume_GS     1259 non-null   float64
#  21  Close_MS      1259 non-null   float64
#  22  Volume_MS     1259 non-null   float64
#  23  Close_WFC     1259 non-null   float64
#  24  Volume_WFC    1259 non-null   float64
#  25  Close_BHC     1259 non-null   float64
#  26  Volume_BHC    1259 non-null   float64
#  27  Close_JNJ     1259 non-null   float64
#  28  Volume_JNJ    1259 non-null   float64
#  29  Close_MRK     1259 non-null   float64
#  30  Volume_MRK    1259 non-null   float64
#  31  Close_PFE     1259 non-null   float64
#  32  Volume_PFE    1259 non-null   float64
#  33  Close_RHHBY   1259 non-null   float64
#  34  Volume_RHHBY  1259 non-null   float64
#  35  Close_UNH     1259 non-null   float64
#  36  Volume_UNH    1259 non-null   float64
#  37  Close_AAPL    1259 non-null   float64
#  38  Volume_AAPL   1259 non-null   int64
#  39  Close_AMZN    1259 non-null   float64
#  40  Volume_AMZN   1259 non-null   float64
#  41  Close_FB      1259 non-null   float64
#  42  Volume_FB     1259 non-null   float64
#  43  Close_GOOG    1259 non-null   float64
#  44  Volume_GOOG   1259 non-null   float64
#  45  Close_IBM     1259 non-null   float64
#  46  Volume_IBM    1259 non-null   float64
#  47  Close_MSFT    1259 non-null   float64
#  48  Volume_MSFT   1259 non-null   float64
#  49  Close_SP500   1259 non-null   float64
#  50  Volume_SP500  1259 non-null   int64
# dtypes: datetime64[ns](1), float64(47), int64(3)
# memory usage: 511.5 KB

# %%
print('Observation: No missing data in AllStocks_df') if sum(AllStocks_df.isnull().sum()) == 0 else (AllStocks_df.isnull().sum())/len(AllStocks_df)
# Out:
# Observation: No missing data in AllStocks_df

# %% [markdown]
# From the above observation, noted that
#
#    1. There are no Nulls or missing values in the final data set.
#
#    2. Data frame has 1259 rows and 51 columns.
#
#    3. Data types are in datetime, int & float types

# %% [markdown]
# Data cleaning and manipulation is completed. Hence, data is now ready to be analysed.

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Performing Calculations
#
#  preparing statistics of dataset for analysis:
#
#  - count - no. of rows
#  - mean (average)
#  - std (standard deviation)
#  - min and max
#  - percentiles 25%, 50%, 75%, 90%, 95% and 99%

# %%
# General Statistical Information
AllStocks_df.describe(percentiles=[.25, .5, .75, .90, .95, .99]).round(2)
# Out:
#        Close_AAL    Volume_AAL  Close_ALGT  Volume_ALGT  Close_ALK  \
# count    1259.00  1.259000e+03     1259.00      1259.00    1259.00
# mean       36.39  1.601068e+07      144.72    180651.95      66.83
# std        11.49  2.921875e+07       24.91    116695.20      15.35
# min         9.04  1.352400e+06       66.23     38000.00      23.56
# max       3531.45  16565000.00    303.91  1.698037e+08     1728.28
#
#        Volume_GOOG  Close_IBM   Volume_IBM  Close_MSFT   Volume_MSFT  \
# count      1259.00    1259.00      1259.00     1259.00  1.259000e+03
# mean    1688060.44     143.65   4565081.10      102.19  2.987749e+07
# std      777636.10      15.16   2669100.77       45.76  1.452097e+07
# min      347500.00      94.77   1193000.00       44.61  7.425600e+06
# 25%     1212900.00     134.33   3093200.00       62.66  2.071000e+07
# 50%     1486200.00     144.24   3857500.00       93.92  2.609770e+07
# 75%     1929000.00     153.42   5094750.00      135.22  3.408930e+07
# 90%     2599420.00     161.89   7044940.00      174.12  4.832358e+07
# 95%     3250750.00     169.13   9086120.00      201.36  5.696580e+07
# 99%     4751542.00     179.92  16081124.00      213.93  8.406215e+07
# max     6653900.00     181.95  30490200.00      231.65  1.352271e+08
#
#        Close_SP500  Volume_SP500
# count      1259.00  1.259000e+03
# mean       2608.43  3.846638e+09
# std         394.74  9.821865e+08
# min        1829.08  1.296540e+09
# 25%        2264.48  3.290665e+09
# 50%        2656.30  3.627610e+09
# 75%        2888.27  4.103015e+09
# 90%        3128.57  4.973074e+09
# 95%        3276.72  5.741216e+09
# 99%        3392.88  7.908099e+09
# max        3580.84  9.044690e+09

# %% [markdown]
# ## Observation

# %%
# Converting the Date column into index for exploring the data 
AllStocks_df = AllStocks_df.set_index ('Date')
AllStocks_df = AllStocks_df.sort_index(ascending=True)

# %%
# Checking the dataframe
AllStocks_df.head()
# Out:
#             Close_AAL  Volume_AAL  Close_ALGT  Volume_ALGT  Close_ALK  \
# Date
# 2015-10-01  39.200001     9175100  217.979996     124000.0  80.230003
# 2015-10-02  38.630001    12276300  215.589996     107700.0  79.260002
# 2015-10-05  40.189999     9421800  216.059998     182100.0  80.910004
# 2015-10-06  38.130001    12985800  208.600006     238200.0  74.529999
# 2015-10-07  39.310001    10513700  213.839996     172800.0  75.970001
#
#             Volume_ALK  Close_DAL  Volume_DAL   Close_HA  Volume_HA  \
# Date
# 2015-10-01   1230100.0  45.410000   8096500.0  24.730000   844900.0
# 2015-10-02   1207900.0  44.869999  10918900.0  24.280001   729500.0
# 2015-10-05   1408800.0  46.959999   8629300.0  25.500000  1220600.0
# 2015-10-06   2874800.0  45.090000   9081000.0  24.250000   972100.0
# 2015-10-07   2894600.0  45.990002  11737900.0  24.559999   799900.0
#
#             Close_LUV  Volume_LUV  Close_BCS  Volume_BCS   Close_CS  \
# Date
# 2015-10-01  38.410000   6147600.0      15.01   2497700.0  24.090000
# 2015-10-02  38.380001   7016100.0      15.39   2775900.0  24.639999
# 2015-10-05  39.299999   5962500.0      15.60   3286900.0  25.160000
# 2015-10-06  38.000000   8334400.0      15.55   2398400.0  25.379999
# 2015-10-07  38.709999   7279800.0      15.73   2624400.0  25.320000
#
#             Volume_CS   Close_DB  Volume_DB    Close_GS  Volume_GS   Close_MS  \
# Date
# 2015-10-01  1152900.0  26.520000  3254600.0  176.020004  3613000.0  31.500000
# 2015-10-02  2076900.0  27.139999  2982700.0  177.009995  4469900.0  31.430000
AllStocks_Price = AllStocks_df[['Close_AAL','Close_ALGT','Close_ALK','Close_DAL','Close_HA','Close_LUV','Close_BCS','Close_CS','Close_DB','Close_GS','Close_MS','Close_WFC','Close_BHC','Close_JNJ','Close_MRK','Close_PFE','Close_RHHBY','Close_UNH','Close_AAPL','Close_AMZN','Close_FB','Close_GOOG','Close_IBM','Close_MSFT','Close_SP500']]
AllStocks_Vol = AllStocks_df[['Volume_AAL','Volume_ALGT','Volume_ALK','Volume_DAL','Volume_HA','Volume_LUV','Volume_BCS','Volume_CS','Volume_DB','Volume_GS','Volume_MS','Volume_WFC','Volume_BHC','Volume_JNJ','Volume_MRK','Volume_PFE','Volume_RHHBY','Volume_UNH','Volume_AAPL','Volume_AMZN','Volume_FB','Volume_GOOG','Volume_IBM','Volume_MSFT','Volume_SP500']]

# %%
AllStocks_Price.describe(percentiles=[.25, .5, .75, .90, .95, .99]).round(2)
# Out:
#        Close_AAL  Close_ALGT  Close_ALK  Close_DAL  Close_HA  Close_LUV  \
# count    1259.00     1259.00    1259.00    1259.00   1259.00    1259.00
# mean       36.39      144.72      66.83      48.22     35.28      49.52
# std        11.49       24.91      15.35       9.38     11.35       8.83
# min         9.04       66.23      23.56      19.19      8.63      23.87
# 25%        30.36      130.08      61.64      45.27     27.80      42.42
# 50%        37.95      144.00      66.15      50.34     36.90      51.88
# 75%        45.11      162.59      75.76      54.74     42.84      55.93
# 90%        49.94      173.53      87.25      57.82     49.17      59.52
# 95%        52.10      177.75      92.01      58.85     51.97      61.72
# 99%        55.30      213.16      96.62      61.63     57.02      65.30
# max        58.47      227.86     100.24      63.16     60.30      66.29
#
#        Close_BCS  Close_CS  Close_DB  Close_GS  Close_MS  Close_WFC  \
# count    1259.00   1259.00   1259.00   1259.00   1259.00    1259.00
# mean        9.32     14.13     13.59    207.44     42.65      49.04
# std         2.19      3.24      5.32     31.60      8.66       9.16
# min         3.84      6.67      5.48    134.97     21.69      22.53
# 25%         8.11     12.00      8.70    183.18     38.23      47.33
# 50%         9.33     13.74     13.47    209.66     44.02      51.14
# 75%        10.78     15.50     17.44    231.67     48.94      54.58
# 90%        11.69     17.91     19.33    245.80     52.64      57.15
# 95%        12.82     20.91     23.33    254.77     54.60      58.81
# 99%        15.45     24.99     28.84    267.61     57.16      63.44
# max        15.81     25.96     30.75    273.38     58.91      65.93
#
#        Close_BHC  Close_JNJ  Close_MRK  Close_PFE  Close_RHHBY  Close_UNH  \
# count    1259.00    1259.00    1259.00    1259.00      1259.00    1259.00
# mean       27.87     129.05      68.03      36.29        33.51     213.13
# std        24.99      13.65      11.55       3.81         4.66      59.43
# min         8.51      93.17      48.59      28.49        26.39     109.23
# 25%        16.83     119.64      58.66      33.47        30.63     160.57
# 50%        22.17     130.98      64.09      35.77        32.04     226.64
# 75%        25.49     139.50      79.38      38.33        34.47     259.75
# 90%        33.51     146.26      84.34      42.60        42.66     290.05
# 95%        91.01     148.65      85.82      43.34        43.96     302.13
# 99%       153.76     152.10      90.39      44.54        45.21     314.09
# max       182.32     155.51      92.04      46.23        46.84     323.70
#
#        Close_AAPL  Close_AMZN  Close_FB  Close_GOOG  Close_IBM  Close_MSFT  \
# count     1259.00     1259.00   1259.00     1259.00    1259.00     1259.00
# mean        47.08     1426.99    163.61     1040.79     143.65      102.19
# std         20.99      668.36     40.05      241.60      15.16       45.76
# min         22.58      482.07     90.95      611.29      94.77       44.61
# 25%         29.82      818.12    129.15      797.46     134.33       62.66
# 50%         42.96     1500.00    167.24     1055.81     144.24       93.92
# 75%         53.87     1828.79    186.89     1196.44     153.42      135.22
# 90%         77.38     2137.87    210.86     1393.51     161.89      174.12
# 95%         91.25     2879.86    235.71     1480.33     169.13      201.36
# 99%        116.44     3275.38    269.91     1566.88     179.92      213.93
# max        134.18     3531.45    303.91     1728.28     181.95      231.65
#
#        Close_SP500
# count      1259.00
# mean       2608.43
# std         394.74
# min        1829.08
# 25%        2264.48
# 50%        2656.30
# 75%        2888.27
# 90%        3128.57
# 95%        3276.72
# 99%        3392.88
# max        3580.84

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "last_expr"

# %% [markdown]
# # Data Visualisation

# %% [markdown]
# we are creating visualizations and communicating our findings based on our analysis.

# %% [markdown]
# ### Data visualisation and Findings

# %%
#Plotting the correlation of Stock Prices
plt.figure(figsize = (20,8))
sns.heatmap(AllStocks_Price.corr(),annot = True)
plt.show()

# %% [markdown]
# **Observation**:
#
#  - Strong Positive Correlation (0.6 to 1): Apple, Amazon, Google, Goldman Sachs, J&J, Merck & Co
#  - Weak Positive Correlation (0 to 0.6): American Airlines, Alaska Air, Hawaiian Holdings.
#  - Negative Correlation (0 to -1): Bausch Health, Credit Suisse, Deutsche Bank.
#  - Ideally, the stocks that have negative correlation with the Index (S&P 500) should be avoided in the portfolio since they may prove to be very risky.

# %%
#Plotting the correlation of Stock Volume
plt.figure(figsize = (20,8))
sns.heatmap(AllStocks_Vol.corr(),annot = True)
plt.show()

# %% [markdown]
# **Obervation**:
#  - S&P500 has a positve correlation with all the stock except with BHC
#  - Correlation of more than 0.6 can be observed in the volumes of DAL, WFC, MS, and the highest is with MSFT - 0.71.

# %%
#Plotting the histogram plots of the Volumes of Stocks
plt.figure(figsize = (30,30))
plt.tight_layout()
feature = AllStocks_Vol.columns
for i in enumerate(feature):
    plt.subplot(5,5, i[0]+1)
    sns.distplot(AllStocks_Vol[i[1]],hist=True)
    
plt.suptitle("Variation in Volume of Stocks",y=0.93)
plt.show()

# %% [markdown]
# **Observation**:
#  - Higher the standard deviation, more volatile is the stock. So, in the above figures a volatile stock will cover more area.
#  - ALGT, DAL, HA, CS, GS, MS, WFC, BHC, RHBY, AAPL, GOOG, IBM --> Volatility can be seen in these stocks.

# %%
#Creating Sub-plots to visualize the stocks volume
AllStocks_Vol.plot(kind = 'line',subplots=True, layout = (7,4),figsize=(20,20))
plt.tight_layout()
plt.suptitle("Variation in Volume of Stocks",y=1.05)
plt.show()

# %% [markdown]
# **Observation**:
#  - AAPL, DAL, LUV ---> the volumes have gone up in 2019-20
#  - Trading volumes have gone down in ALK, BCS, DB, BHC, JNJ and PFE.
#  - The volume movement in most technology stocks is observed in sync with S&P 500.

# %%
#Creating Sub-plots to visualize the stocks movement
AllStocks_Price.plot(kind = 'line',subplots=True, layout = (7,4),figsize=(20,20))
plt.tight_layout()
plt.suptitle("Variation in Closing Price of Stocks",y=1.05)
plt.show()

# %% [markdown]
# **Observation**:
#  - We should consider stocks that have a positive movement suggesting that the price has increased during the given period
#  - Also, it suggests that the prices are expected to show an uptrend in the future.
#  - The price of aviation and banking stocks has gone down. The highest drop in the prices can be observed in DB and BHC.

# %% [markdown]
# **Normalisation**:
#
# The stock prices of various stocks here are on different scales. Hence, we need to perform normalisation to have them on the same scale for analysis

# %%
# Replicating the original dataframe for this purpose

AllStocks_Price_Normalized=AllStocks_Price.copy()

# Checking the data

AllStocks_Price_Normalized.head()
# Out:
#             Close_AAL  Close_ALGT  Close_ALK  Close_DAL   Close_HA  Close_LUV  \
# Date
# 2015-10-01  39.200001  217.979996  80.230003  45.410000  24.730000  38.410000
# 2015-10-02  38.630001  215.589996  79.260002  44.869999  24.280001  38.380001
# 2015-10-05  40.189999  216.059998  80.910004  46.959999  25.500000  39.299999
# 2015-10-06  38.130001  208.600006  74.529999  45.090000  24.250000  38.000000
# 2015-10-07  39.310001  213.839996  75.970001  45.990002  24.559999  38.709999
#
#             Close_BCS   Close_CS   Close_DB    Close_GS   Close_MS  Close_WFC  \
# Date
# 2015-10-01      15.01  24.090000  26.520000  176.020004  31.500000  51.439999
# 2015-10-02      15.39  24.639999  27.139999  177.009995  31.430000  51.259998
# 2015-10-05      15.60  25.160000  28.200001  180.699997  32.290001  52.410000
# 2015-10-06      15.55  25.379999  28.400000  180.320007  32.360001  52.029999
# 2015-10-07      15.73  25.320000  28.790001  182.229996  32.930000  52.189999
#
#              Close_BHC  Close_JNJ  Close_MRK  Close_PFE  Close_RHHBY  \
# Date
# 2015-10-01  179.600006  93.169998  49.369999  31.840000    33.220001
# 2015-10-02  182.320007  93.930000  50.139999  33.080002    33.320000
# 2015-10-05  163.460007  94.760002  51.230000  33.480000    33.439999
# 2015-10-06  166.000000  93.419998  49.799999  32.790001    33.529999
# 2015-10-07  169.830002  94.980003  50.950001  33.290001    32.549999
#
#              Close_UNH  Close_AAPL  Close_AMZN   Close_FB  Close_GOOG  \
# Date
# 2015-10-01  116.610001   27.395000  520.719971  90.949997  611.289978
# 2015-10-02  118.830002   27.594999  532.539978  92.070000  626.909973
# 2015-10-05  119.650002   27.695000  543.679993  94.010002  641.469971
# 2015-10-06  116.050003   27.827499  537.479980  92.800003  645.440002
# 2015-10-07  116.430000   27.695000  541.940002  92.400002  642.359985
#
#              Close_IBM  Close_MSFT  Close_SP500
# Date
# 2015-10-01  143.589996   44.610001  1923.819946
# 2015-10-02  144.580002   45.570000  1951.359985
# 2015-10-05  149.039993   46.630001  1987.050049
# 2015-10-06  148.779999   46.750000  1979.920044
# 2015-10-07  150.089996   46.799999  1995.829956

# %%
# Normalizing the Data 
for column in AllStocks_Price_Normalized.columns:
     AllStocks_Price_Normalized[column] = AllStocks_Price_Normalized[column]  / AllStocks_Price_Normalized[column][0]
        
# Checking the dataframe after normalization
AllStocks_Price_Normalized.head()
# Out:
#             Close_AAL  Close_ALGT  Close_ALK  Close_DAL  Close_HA  Close_LUV  \
# Date
# 2015-10-01   1.000000    1.000000   1.000000   1.000000  1.000000   1.000000
# 2015-10-02   0.985459    0.989036   0.987910   0.988108  0.981804   0.999219
# 2015-10-05   1.025255    0.991192   1.008476   1.034133  1.031136   1.023171
# 2015-10-06   0.972704    0.956969   0.928954   0.992953  0.980590   0.989326
# 2015-10-07   1.002806    0.981007   0.946903   1.012773  0.993126   1.007810
#
#             Close_BCS  Close_CS  Close_DB  Close_GS  Close_MS  Close_WFC  \
# Date
# 2015-10-01   1.000000  1.000000  1.000000  1.000000  1.000000   1.000000
# 2015-10-02   1.025316  1.022831  1.023379  1.005624  0.997778   0.996501
# 2015-10-05   1.039307  1.044417  1.063348  1.026588  1.025079   1.018857
# 2015-10-06   1.035976  1.053549  1.070890  1.024429  1.027302   1.011470
# 2015-10-07   1.047968  1.051059  1.085596  1.035280  1.045397   1.014580
#
#             Close_BHC  Close_JNJ  Close_MRK  Close_PFE  Close_RHHBY  \
# Date
# 2015-10-01   1.000000   1.000000   1.000000   1.000000     1.000000
# 2015-10-02   1.015145   1.008157   1.015597   1.038945     1.003010
# 2015-10-05   0.910134   1.017066   1.037675   1.051508     1.006622
# 2015-10-06   0.924276   1.002683   1.008710   1.029837     1.009332
# 2015-10-07   0.945601   1.019427   1.032003   1.045540     0.979831
#
#             Close_UNH  Close_AAPL  Close_AMZN  Close_FB  Close_GOOG  \
# Date
# 2015-10-01   1.000000    1.000000    1.000000  1.000000    1.000000
# 2015-10-02   1.019038    1.007301    1.022699  1.012314    1.025553
# 2015-10-05   1.026070    1.010951    1.044093  1.033645    1.049371
# 2015-10-06   0.995198    1.015788    1.032186  1.020341    1.055866
# 2015-10-07   0.998456    1.010951    1.040751  1.015943    1.050827
#
#             Close_IBM  Close_MSFT  Close_SP500
# Date
# 2015-10-01   1.000000    1.000000     1.000000
# 2015-10-02   1.006895    1.021520     1.014315
# 2015-10-05   1.037955    1.045281     1.032867
# 2015-10-06   1.036145    1.047971     1.029161
# 2015-10-07   1.045268    1.049092     1.037431

# %% [markdown]
# **Observation**:
#
# After normalization, the values are in the range of -1 to 1.

# %% [markdown]
# **Now we will observe the visualisation of normalised data - as it becomes easier for us to compare the performance.**

# %%
# Plotting Normalized Stock Prices against Index
plt.figure(figsize=(20,30))
plt.subplot(4,3,1)
sns.lineplot(data = AllStocks_Price_Normalized[['Close_AAL','Close_ALGT','Close_SP500']])
plt.legend(loc='best')
plt.tight_layout()
plt.subplot(4,3,2)
sns.lineplot(data = AllStocks_Price_Normalized[['Close_ALK','Close_DAL','Close_SP500']])
plt.legend(loc='best')
plt.tight_layout()
plt.subplot(4,3,3)
sns.lineplot(data = AllStocks_Price_Normalized[['Close_HA','Close_LUV','Close_SP500']])
plt.legend(loc='best')
plt.tight_layout()
plt.subplot(4,3,4)
sns.lineplot(data = AllStocks_Price_Normalized[['Close_BCS','Close_CS','Close_SP500']])
plt.legend(loc='best')
plt.tight_layout()
plt.subplot(4,3,5)
sns.lineplot(data = AllStocks_Price_Normalized[['Close_DB','Close_GS','Close_SP500']])
plt.legend(loc='best')
plt.tight_layout()
plt.subplot(4,3,6)
sns.lineplot(data = AllStocks_Price_Normalized[['Close_MS','Close_WFC','Close_SP500']])
plt.legend(loc='best')
plt.tight_layout()
plt.subplot(4,3,7)
sns.lineplot(data = AllStocks_Price_Normalized[['Close_BHC','Close_JNJ','Close_SP500']])
plt.legend(loc='best')
plt.tight_layout()
plt.subplot(4,3,8)
sns.lineplot(data = AllStocks_Price_Normalized[['Close_MRK','Close_PFE','Close_SP500']])
plt.legend(loc='best')
plt.tight_layout()
plt.subplot(4,3,9)
sns.lineplot(data = AllStocks_Price_Normalized[['Close_RHHBY','Close_UNH','Close_SP500']])
plt.legend(loc='best')
plt.tight_layout()
plt.subplot(4,3,10)
sns.lineplot(data = AllStocks_Price_Normalized[['Close_AAPL','Close_AMZN','Close_SP500']])
plt.legend(loc='best')
plt.tight_layout()
plt.subplot(4,3,11)
sns.lineplot(data = AllStocks_Price_Normalized[['Close_FB','Close_GOOG','Close_SP500']])
plt.legend(loc='best')
plt.tight_layout()
plt.subplot(4,3,12)
sns.lineplot(data = AllStocks_Price_Normalized[['Close_IBM','Close_MSFT','Close_SP500']])
plt.legend(loc='best')
plt.tight_layout()
plt.suptitle("Stocks Movement v/s Index",y=1.05)
plt.show()

# %% [markdown]
# **Observation**:
#  - MSFT< GOOG, FB, AAPL, AMZN are showing an uptrend, whereas IBM is showing a downtrend.
#  - In healthcare - BHC and PFE are showing a downtrend
#  - In Finance - DB, BCS, CS and WFC are showing a downtrend
#  - In avaiation - HA, DAL, AAL are showing a downtrend.

# %% [markdown]
# **Daily returns**

# %%
AllStocks_Price_returns = AllStocks_Price.pct_change()

AllStocks_Price_returns = round((AllStocks_Price_returns[1:]*100),2)
AllStocks_Price_returns.head()
# Out:
#             Close_AAL  Close_ALGT  Close_ALK  Close_DAL  Close_HA  Close_LUV  \
# Date
# 2015-10-02      -1.45       -1.10      -1.21      -1.19     -1.82      -0.08
# 2015-10-05       4.04        0.22       2.08       4.66      5.02       2.40
# 2015-10-06      -5.13       -3.45      -7.89      -3.98     -4.90      -3.31
# 2015-10-07       3.09        2.51       1.93       2.00      1.28       1.87
# 2015-10-08       1.09       -0.55      -0.28      -0.07      6.23       0.13
#
#             Close_BCS  Close_CS  Close_DB  Close_GS  Close_MS  Close_WFC  \
# Date
# 2015-10-02       2.53      2.28      2.34      0.56     -0.22      -0.35
# 2015-10-05       1.36      2.11      3.91      2.08      2.74       2.24
# 2015-10-06      -0.32      0.87      0.71     -0.21      0.22      -0.73
# 2015-10-07       1.16     -0.24      1.37      1.06      1.76       0.31
# 2015-10-08       0.51     -3.12     -1.39     -0.64      0.18       0.67
#
#             Close_BHC  Close_JNJ  Close_MRK  Close_PFE  Close_RHHBY  \
# Date
# 2015-10-02       1.51       0.82       1.56       3.89         0.30
# 2015-10-05     -10.34       0.88       2.17       1.21         0.36
# 2015-10-06       1.55      -1.41      -2.79      -2.06         0.27
# 2015-10-07       2.31       1.67       2.31       1.52        -2.92
# 2015-10-08       0.79       0.11       0.14      -0.60         2.15
#
#             Close_UNH  Close_AAPL  Close_AMZN  Close_FB  Close_GOOG  \
# Date
# 2015-10-02       1.90        0.73        2.27      1.23        2.56
# 2015-10-05       0.69        0.36        2.09      2.11        2.32
# 2015-10-06      -3.01        0.48       -1.14     -1.29        0.62
# 2015-10-07       0.33       -0.48        0.83     -0.43       -0.48
# 2015-10-08      -0.30       -1.16       -1.62      0.08       -0.50
#
#             Close_IBM  Close_MSFT  Close_SP500
# Date
# 2015-10-02       0.69        2.15         1.43
# 2015-10-05       3.08        2.33         1.83
# 2015-10-06      -0.17        0.26        -0.36
# 2015-10-07       0.88        0.11         0.80
# 2015-10-08       1.46        1.39         0.88

# %%
plt.figure(figsize=(15,15))
plt.subplot(2,2,1)
sns.distplot(AllStocks_Price_returns[['Close_AAL']],hist=True,label="AAL_Return")
sns.distplot(AllStocks_Price_returns[['Close_ALGT']],hist=True,label="ALGT_Return")
sns.distplot(AllStocks_Price_returns[['Close_ALK']],hist=True,label="ALK_Return")
sns.distplot(AllStocks_Price_returns[['Close_DAL']],hist=True,label="DAL_Return")
sns.distplot(AllStocks_Price_returns[['Close_HA']],hist=True,label="HA_Return")
sns.distplot(AllStocks_Price_returns[['Close_LUV']],hist=True,label="LUV_Return")
plt.legend()
plt.subplot(2,2,2)
sns.distplot(AllStocks_Price_returns[['Close_BCS']],hist=True,label="AAL_Return")
sns.distplot(AllStocks_Price_returns[['Close_CS']],hist=True,label="CS_Return")
sns.distplot(AllStocks_Price_returns[['Close_DB']],hist=True,label="DB_Return")
sns.distplot(AllStocks_Price_returns[['Close_GS']],hist=True,label="GS_Return")
sns.distplot(AllStocks_Price_returns[['Close_MS']],hist=True,label="MS_Return")
sns.distplot(AllStocks_Price_returns[['Close_WFC']],hist=True,label="WFC_Return")
plt.legend()
plt.subplot(2,2,3)
sns.distplot(AllStocks_Price_returns[['Close_BHC']],hist=True,label="BHC_Return")
sns.distplot(AllStocks_Price_returns[['Close_JNJ']],hist=True,label="JNJ_Return")
sns.distplot(AllStocks_Price_returns[['Close_MRK']],hist=True,label="MRK_Return")
sns.distplot(AllStocks_Price_returns[['Close_PFE']],hist=True,label="PFE_Return")
sns.distplot(AllStocks_Price_returns[['Close_RHHBY']],hist=True,label="RHHBY_Return")
sns.distplot(AllStocks_Price_returns[['Close_UNH']],hist=True,label="UNH_Return")
plt.legend()
plt.subplot(2,2,4)
sns.distplot(AllStocks_Price_returns[['Close_AAPL']],hist=True,label="AAPL_Return")
sns.distplot(AllStocks_Price_returns[['Close_AMZN']],hist=True,label="AMZN_Return")
sns.distplot(AllStocks_Price_returns[['Close_FB']],hist=True,label="FB_Return")
sns.distplot(AllStocks_Price_returns[['Close_GOOG']],hist=True,label="GOOG_Return")
sns.distplot(AllStocks_Price_returns[['Close_IBM']],hist=True,label="IBM_Return")
sns.distplot(AllStocks_Price_returns[['Close_MSFT']],hist=True,label="MSFT_Return")
plt.legend()
plt.suptitle("Stock Price Spread/Volatility",y=0.95)
plt.show()

# %% [markdown]
# **Relative Stock Price - Change in Stock Price wrt Index**

# %%
AllStockvsIndex = AllStocks_Price.copy()
for column in AllStockvsIndex.columns:
    AllStockvsIndex[column] = AllStockvsIndex[column]/AllStockvsIndex['Close_SP500']

# %%
# Checking the data
AllStockvsIndex.head()
# Out:
#             Close_AAL  Close_ALGT  Close_ALK  Close_DAL  Close_HA  Close_LUV  \
# Date
# 2015-10-01   0.020376    0.113306   0.041703   0.023604  0.012855   0.019965
# 2015-10-02   0.019796    0.110482   0.040618   0.022994  0.012443   0.019668
# 2015-10-05   0.020226    0.108734   0.040719   0.023633  0.012833   0.019778
# 2015-10-06   0.019258    0.105358   0.037643   0.022774  0.012248   0.019193
# 2015-10-07   0.019696    0.107143   0.038064   0.023043  0.012306   0.019395
#
#             Close_BCS  Close_CS  Close_DB  Close_GS  Close_MS  Close_WFC  \
# Date
# 2015-10-01   0.007802  0.012522  0.013785  0.091495  0.016374   0.026738
# 2015-10-02   0.007887  0.012627  0.013908  0.090711  0.016107   0.026269
# 2015-10-05   0.007851  0.012662  0.014192  0.090939  0.016250   0.026376
# 2015-10-06   0.007854  0.012819  0.014344  0.091074  0.016344   0.026279
# 2015-10-07   0.007881  0.012686  0.014425  0.091305  0.016499   0.026150
#
#             Close_BHC  Close_JNJ  Close_MRK  Close_PFE  Close_RHHBY  \
# Date
# 2015-10-01   0.093356   0.048430   0.025662   0.016550     0.017268
# 2015-10-02   0.093432   0.048136   0.025695   0.016952     0.017075
# 2015-10-05   0.082263   0.047689   0.025782   0.016849     0.016829
# 2015-10-06   0.083842   0.047184   0.025153   0.016561     0.016935
# 2015-10-07   0.085092   0.047589   0.025528   0.016680     0.016309
#
#             Close_UNH  Close_AAPL  Close_AMZN  Close_FB  Close_GOOG  \
# Date
# 2015-10-01   0.060614    0.014240    0.270670  0.047276    0.317748
# 2015-10-02   0.060896    0.014141    0.272907  0.047182    0.321268
# 2015-10-05   0.060215    0.013938    0.273612  0.047311    0.322825
# 2015-10-06   0.058613    0.014055    0.271465  0.046871    0.325993
# 2015-10-07   0.058337    0.013876    0.271536  0.046297    0.321851
#
#             Close_IBM  Close_MSFT  Close_SP500
# Date
# 2015-10-01   0.074638    0.023188          1.0
# 2015-10-02   0.074092    0.023353          1.0
# 2015-10-05   0.075006    0.023467          1.0
# 2015-10-06   0.075144    0.023612          1.0
# 2015-10-07   0.075202    0.023449          1.0

# %%
# Plotting the Relative Stock Price change 
AllStockvsIndex.plot(kind = 'line',subplots=True, layout = (7,4),figsize=(20,20))
plt.tight_layout()
plt.suptitle("Relative Stock Prices wrt Market Index",y=1.05)
# Out:
# Text(0.5, 1.05, 'Relative Stock Prices wrt Market Index')

# %%
# Checking the statistical values for daily returns of stocks
AllStocks_Price_returns.describe()
# Out:
#          Close_AAL   Close_ALGT    Close_ALK    Close_DAL     Close_HA  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1258.000000
# mean     -0.033808    -0.004714    -0.025548     0.004237     0.003529
# std       3.472455     2.910028     2.690616     2.647849     3.313180
# min     -25.220000   -28.330000   -23.240000   -25.990000   -26.500000
# 25%      -1.360000    -1.130000    -1.070000    -0.970000    -1.490000
# 50%      -0.050000    -0.040000     0.025000     0.080000     0.030000
# 75%       1.320000     1.165000     1.060000     0.977500     1.510000
# max      41.100000    29.240000    20.310000    21.020000    24.580000
#
#          Close_LUV    Close_BCS     Close_CS     Close_DB     Close_GS  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1258.000000
# mean      0.024666    -0.054754    -0.043760    -0.052925     0.030286
# std       2.291209     2.511813     2.283985     2.774197     1.989936
# min     -15.110000   -21.850000   -18.260000   -17.490000   -12.710000
# 25%      -0.920000    -1.080000    -1.040000    -1.497500    -0.837500
# 50%       0.060000     0.000000     0.000000    -0.105000     0.030000
# 75%       1.000000     1.020000     1.040000     1.390000     0.970000
# max      14.440000    15.100000    16.340000    14.020000    17.580000
#
#           Close_MS    Close_WFC    Close_BHC    Close_JNJ    Close_MRK  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1258.000000
# mean      0.057886    -0.041494    -0.089626     0.045032     0.051264
# std       2.181011     2.034980     4.454969     1.245863     1.406699
# min     -15.600000   -15.870000   -51.460000   -10.040000    -8.900000
# 25%      -0.900000    -0.790000    -1.967500    -0.430000    -0.620000
# 50%       0.045000    -0.040000    -0.050000     0.050000     0.020000
# 75%       1.047500     0.757500     1.800000     0.590000     0.760000
# max      19.770000    14.530000    33.740000     8.000000    10.410000
#
#          Close_PFE  Close_RHHBY    Close_UNH   Close_AAPL   Close_AMZN  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1258.000000
# mean      0.020572     0.029308     0.094062     0.132138     0.161033
# std       1.382649     1.351350     1.780985     1.872844     1.896930
# min      -7.730000    -8.960000   -17.280000   -12.860000    -7.920000
# 25%      -0.590000    -0.627500    -0.660000    -0.620000    -0.670000
# 50%       0.010000     0.020000     0.080000     0.100000     0.160000
# 75%       0.637500     0.690000     0.817500     0.990000     1.077500
# max       8.960000    13.010000    12.800000    11.980000    13.220000
#
#           Close_FB   Close_GOOG    Close_IBM   Close_MSFT  Close_SP500
# count  1258.000000  1258.000000  1258.000000  1258.000000  1258.000000
# mean      0.105079     0.083498    -0.000207     0.138625     0.051733
# std       2.035461     1.652143     1.608626     1.753969     1.207997
# min     -18.960000   -11.100000   -12.850000   -14.740000   -11.980000
# 25%      -0.720000    -0.577500    -0.650000    -0.590000    -0.290000
# 50%       0.120000     0.100000     0.050000     0.120000     0.070000
# 75%       1.090000     0.880000     0.687500     0.920000     0.520000
# max      15.520000    10.450000    11.300000    14.220000     9.380000

# %% [markdown]
# **Annualized Risk, Annualized Returns, Cumulative Returns and Sharpe Ratio**

# %%
#Calculating Annualized_Returns

Annualized_Returns = []
col=[]

for i in AllStocks_Price_returns.columns:
    col.append(i)

for i in AllStocks_Price_returns.columns:
    Annualized_Returns.append(AllStocks_Price_returns[i].mean()*252)

# %%
# Creating a dataframe and stocks values for each stock
Annualized_df=pd.DataFrame(list(zip(col,Annualized_Returns)),columns =['Stocks', 'AnnualizedReturns'])

# %%
# Renaming the names of stocks
for i in Annualized_df.index:
    Annualized_df['Stocks'][i]=Annualized_df['Stocks'][i].replace("Close_","")

# %%
# Checking the data
Annualized_df
# Out:
#    Stocks  AnnualizedReturns
# 0     AAL          -8.519523
# 1    ALGT          -1.187886
# 2     ALK          -6.438219
# 3     DAL           1.067695
# 4      HA           0.889412
# 5     LUV           6.215866
# 6     BCS         -13.797901
# 7      CS         -11.027504
# 8      DB         -13.337170
# 9      GS           7.632114
# 10     MS          14.587154
# 11    WFC         -10.456598
# 12    BHC         -22.585851
# 13    JNJ          11.348013
# 14    MRK          12.918506
# 15    PFE           5.184229
# 16  RHHBY           7.385723
# 17    UNH          23.703625
# 18   AAPL          33.298855
# 19   AMZN          40.580413
# 20     FB          26.480032
# 21   GOOG          21.041399
# 22    IBM          -0.052083
# 23   MSFT          34.933450
# 24  SP500          13.036693

# %% [markdown]
# **Observation**:
#  - All tech stocks have given positive returns except IBM. The highest returns have been given by AMZN followed by MSFT followed by AAPL.
#  - Highest negative return was in health care - BHC to the tune of -22%.
#  - In healthcare, UNH has given highest positive return - 23%.
#  - In Finance, barring GS and MS, all stocks have given negative returns.
#  - The lowest positive returns have been observed in Aviation industry - HA at 0.88%, followed by DAL at 1.06%

# %%
#Calculating Annualized_Risk
Annualized_Risk = []

for i in AllStocks_Price_returns.columns:
    Annualized_Risk.append(AllStocks_Price_returns[i].std()*np.sqrt(252))

# %%
# Adding Annualized Risk column to the dataframe
Annualized_df['AnnualizedRisk']= Annualized_Risk

# %%
# Checking the data
Annualized_df
# Out:
#    Stocks  AnnualizedReturns  AnnualizedRisk
# 0     AAL          -8.519523       55.123508
# 1    ALGT          -1.187886       46.195261
# 2     ALK          -6.438219       42.712205
# 3     DAL           1.067695       42.033298
# 4      HA           0.889412       52.595107
# 5     LUV           6.215866       36.371822
# 6     BCS         -13.797901       39.873802
# 7      CS         -11.027504       36.257140
# 8      DB         -13.337170       44.039005
# 9      GS           7.632114       31.589258
# 10     MS          14.587154       34.622473
# 11    WFC         -10.456598       32.304313
# 12    BHC         -22.585851       70.720438
# 13    JNJ          11.348013       19.777468
# 14    MRK          12.918506       22.330662
# 15    PFE           5.184229       21.948868
# 16  RHHBY           7.385723       21.452019
# 17    UNH          23.703625       28.272255
# 18   AAPL          33.298855       29.730469
# 19   AMZN          40.580413       30.112837
# 20     FB          26.480032       32.311941
# 21   GOOG          21.041399       26.226954
# 22    IBM          -0.052083       25.536147
# 23   MSFT          34.933450       27.843398
# 24  SP500          13.036693       19.176361

# %% [markdown]
# **Observation**:
#  - In aviation industry, the risk is high, whereas the returns are low or negative
#  - In BHC, the annualised risk is highest, giving us highest negative returns - 22%.
#  - Technology stocks have compparatively lower risk and higher returns
#  - We should consider risk factor while making a portfolio, since though there could be an uptrend, there could be higher risk involved too.

# %%
#Calculating Cummulative_returns

Cumulative_ret =[]
for i in AllStocks_Price_returns.columns:
    Cumulative_ret.append(AllStocks_Price[i][-1]/AllStocks_Price[i][0]-1)

# %%
# Adding Cumulative_ret column to the dataframe
Annualized_df['Cumulative_ret']= Cumulative_ret

# %%
Annualized_df['Cumulative_ret']=round(Annualized_df['Cumulative_ret'],4)*100

# %%
# Checking the data
Annualized_df.head()
# Out:
#   Stocks  AnnualizedReturns  AnnualizedRisk  Cumulative_ret
# 0    AAL          -8.519523       55.123508          -68.65
# 1   ALGT          -1.187886       46.195261          -45.04
# 2    ALK          -6.438219       42.712205          -54.34
# 3    DAL           1.067695       42.033298          -32.66
# 4     HA           0.889412       52.595107          -47.88

# %%
#Calculating Sharpe Ratio with 0.75% rfr
Annualized_df['Sharpe_Ratio'] = (Annualized_df['AnnualizedReturns']-0.0075)/Annualized_df['AnnualizedRisk']

# %%
# checking the data
Annualized_df
# Out:
#    Stocks  AnnualizedReturns  AnnualizedRisk  Cumulative_ret  Sharpe_Ratio
# 0     AAL          -8.519523       55.123508          -68.65     -0.154689
# 1    ALGT          -1.187886       46.195261          -45.04     -0.025877
# 2     ALK          -6.438219       42.712205          -54.34     -0.150910
# 3     DAL           1.067695       42.033298          -32.66      0.025223
# 4      HA           0.889412       52.595107          -47.88      0.016768
# 5     LUV           6.215866       36.371822           -2.37      0.170692
# 6     BCS         -13.797901       39.873802          -66.62     -0.346227
# 7      CS         -11.027504       36.257140          -58.61     -0.304354
# 8      DB         -13.337170       44.039005          -68.33     -0.303019
# 9      GS           7.632114       31.589258           14.17      0.241367
# 10     MS          14.587154       34.622473           53.49      0.421104
# 11    WFC         -10.456598       32.304313          -54.30     -0.323923
# 12    BHC         -22.585851       70.720438          -91.35     -0.319474
# 13    JNJ          11.348013       19.777468           59.79      0.573406
# 14    MRK          12.918506       22.330662           68.02      0.578174
# 15    PFE           5.184229       21.948868           15.26      0.235854
# 16  RHHBY           7.385723       21.452019           28.87      0.343941
# 17    UNH          23.703625       28.272255          167.36      0.838141
# 18   AAPL          33.298855       29.730469          322.74      1.119772
# 19   AMZN          40.580413       30.112837          504.69      1.347363
# 20     FB          26.480032       32.311941          187.96      0.819280
# 21   GOOG          21.041399       26.226954          140.41      0.801996
# 22    IBM          -0.052083       25.536147          -15.27     -0.002333
# 23   MSFT          34.933450       27.843398          371.49      1.254371
# 24  SP500          13.036693       19.176361           74.81      0.679440

# %%
# Getting rid of the Stocks having negetive Annualized returns
newAnnualized_df=Annualized_df.loc[(Annualized_df.AnnualizedReturns > 0.0)]
newAnnualized_df
# Out:
#    Stocks  AnnualizedReturns  AnnualizedRisk  Cumulative_ret  Sharpe_Ratio
# 3     DAL           1.067695       42.033298          -32.66      0.025223
# 4      HA           0.889412       52.595107          -47.88      0.016768
# 5     LUV           6.215866       36.371822           -2.37      0.170692
# 9      GS           7.632114       31.589258           14.17      0.241367
# 10     MS          14.587154       34.622473           53.49      0.421104
# 13    JNJ          11.348013       19.777468           59.79      0.573406
# 14    MRK          12.918506       22.330662           68.02      0.578174
# 15    PFE           5.184229       21.948868           15.26      0.235854
# 16  RHHBY           7.385723       21.452019           28.87      0.343941
# 17    UNH          23.703625       28.272255          167.36      0.838141
# 18   AAPL          33.298855       29.730469          322.74      1.119772
# 19   AMZN          40.580413       30.112837          504.69      1.347363
# 20     FB          26.480032       32.311941          187.96      0.819280
# 21   GOOG          21.041399       26.226954          140.41      0.801996
# 23   MSFT          34.933450       27.843398          371.49      1.254371
# 24  SP500          13.036693       19.176361           74.81      0.679440

# %% [markdown]
# **Observation**:
#  - Highest cumulative returns have been provided by technology stocks except IBM.
#  - To be in sync with the investment goals of the investors, we will not include any stocks giving negative returns in the portfolio.

# %%
# Getting rid of the Stocks having negetive Cummulative returns
newAnnualized_df=newAnnualized_df.loc[(Annualized_df.Cumulative_ret > 0)]
newAnnualized_df
# Out:
#    Stocks  AnnualizedReturns  AnnualizedRisk  Cumulative_ret  Sharpe_Ratio
# 9      GS           7.632114       31.589258           14.17      0.241367
# 10     MS          14.587154       34.622473           53.49      0.421104
# 13    JNJ          11.348013       19.777468           59.79      0.573406
# 14    MRK          12.918506       22.330662           68.02      0.578174
# 15    PFE           5.184229       21.948868           15.26      0.235854
# 16  RHHBY           7.385723       21.452019           28.87      0.343941
# 17    UNH          23.703625       28.272255          167.36      0.838141
# 18   AAPL          33.298855       29.730469          322.74      1.119772
# 19   AMZN          40.580413       30.112837          504.69      1.347363
# 20     FB          26.480032       32.311941          187.96      0.819280
# 21   GOOG          21.041399       26.226954          140.41      0.801996
# 23   MSFT          34.933450       27.843398          371.49      1.254371
# 24  SP500          13.036693       19.176361           74.81      0.679440

# %%
newAnnualized_df.sort_values(by=['Sharpe_Ratio'],ascending=[False])
# Out:
#    Stocks  AnnualizedReturns  AnnualizedRisk  Cumulative_ret  Sharpe_Ratio
# 19   AMZN          40.580413       30.112837          504.69      1.347363
# 23   MSFT          34.933450       27.843398          371.49      1.254371
# 18   AAPL          33.298855       29.730469          322.74      1.119772
# 17    UNH          23.703625       28.272255          167.36      0.838141
# 20     FB          26.480032       32.311941          187.96      0.819280
# 21   GOOG          21.041399       26.226954          140.41      0.801996
# 24  SP500          13.036693       19.176361           74.81      0.679440
# 14    MRK          12.918506       22.330662           68.02      0.578174
# 13    JNJ          11.348013       19.777468           59.79      0.573406
# 10     MS          14.587154       34.622473           53.49      0.421104
# 16  RHHBY           7.385723       21.452019           28.87      0.343941
# 9      GS           7.632114       31.589258           14.17      0.241367
# 15    PFE           5.184229       21.948868           15.26      0.235854

# %% [markdown]
# **Observation**:
#  - The ideal sharpe ratio is 1 and above. Stocks with negative sharpe ratio should not be included in the portfolio.

# %% [markdown]
# In the final step, we will be delivering our insights and providing recommendations based on our analysis.

# %% [markdown]
#  - **Aggressive Portfolio for Peter**: Peter's portfolio, though aggressive, we have made it a point that he gets an exposure to all industries. Since he is young and willing to take risks, we have given him a well diversified portfolio.
#
#     1. AMZN- 15%
#     2. MSFT - 15%
#     3. Apple - 12%
#     4. FB - 10%
#     5. Google - 8%
#     6. MRk - 12%
#     7. JNJ - 10%
#     8. RHHBY - 10%
#     9. GS - 5%
#     10. PFE - 5%
#
# - **Conservative Porfolio for Patrick**: Conservative portfolio with lower risk and good returns
#
#     1. AMZN- 15%
#     2. MSFT - 17%
#     3. Apple - 12%
#     4. Google - 12%
#     5. MRk - 10%
#     6. JNJ - 10%
#     7. RHHBY - 12%
#     8. GS - 4%
#     9. PFE - 8%
